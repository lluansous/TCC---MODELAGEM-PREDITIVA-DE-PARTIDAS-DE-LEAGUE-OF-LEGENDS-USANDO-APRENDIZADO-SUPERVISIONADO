# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar e filtrar dados
df = pd.read_csv('lol.csv')
# Out:
# <ipython-input-1-b80fe87cd9eb>:7: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('lol.csv')

# %%
print(f"Shape: {df.shape}")
print("\nInformações básicas:")
print(df.info())
print("\nValores únicos por coluna:")
print(df.nunique())
print("\nEstatísticas descritivas:")
print(df.describe(include='all'))
# Out:
# Shape: (10800, 161)
#
# Informações básicas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10800 entries, 0 to 10799
# Columns: 161 entries, gameid to opp_deathsat25
# dtypes: float64(118), int64(20), object(23)
# memory usage: 13.3+ MB
# None
#
# Valores únicos por coluna:
# gameid              900
# datacompleteness      2
# url                  21
# league               23
# year                  1
#                    ...
# assistsat25          18
# deathsat25           11
# opp_killsat25        11
# opp_assistsat25      18
# opp_deathsat25       11
# Length: 161, dtype: int64
#
# Estatísticas descritivas:
#                   gameid datacompleteness  \
# count              10800            10800
# unique               900                2
# top     LOLTMNT03_179647         complete
# freq                  12             9876
# mean                 NaN              NaN
# std                  NaN              NaN
# min                  NaN              NaN
# 25%                  NaN              NaN
# 50%                  NaN              NaN
# 75%                  NaN              NaN
# max                  NaN              NaN
#
#                                                  url league     year   split  \
# count                                            924  10800  10800.0   10104
# unique                                            21     23      NaN       7
# top     https://lpl.qq.com/es/stats.shtml?bmid=11733    LCK      NaN  Winter
# freq                                              60    984      NaN    4776
# mean                                             NaN    NaN   2025.0     NaN
# std                                              NaN    NaN      0.0     NaN
# min                                              NaN    NaN   2025.0     NaN
# 25%                                              NaN    NaN   2025.0     NaN
# 50%                                              NaN    NaN   2025.0     NaN
# 75%                                              NaN    NaN   2025.0     NaN
# max                                              NaN    NaN   2025.0     NaN
#
#         playoffs                 date          game         patch  ...  \
# count    10800.0                10800  10800.000000  10800.000000  ...
# unique       NaN                  899           NaN           NaN  ...
# top          NaN  2025-02-05 20:08:47           NaN           NaN  ...
# freq         NaN                   24           NaN           NaN  ...
# mean         0.0                  NaN      1.512222     15.017867  ...
# std          0.0                  NaN      0.795067      0.006592  ...
# min          0.0                  NaN      1.000000     15.010000  ...
# 25%          0.0                  NaN      1.000000     15.010000  ...
# 50%          0.0                  NaN      1.000000     15.020000  ...
# 75%          0.0                  NaN      2.000000     15.020000  ...
# max          0.0                  NaN      5.000000     15.030000  ...
#
#          opp_csat25  golddiffat25    xpdiffat25   csdiffat25    killsat25  \
# count   9300.000000   9300.000000   9300.000000  9300.000000  9300.000000
# unique          NaN           NaN           NaN          NaN          NaN
# top             NaN           NaN           NaN          NaN          NaN
# freq            NaN           NaN           NaN          NaN          NaN
# mean     280.686022      0.000000      0.000000     0.000000     0.027312
# std      261.679844   2852.191134   2546.002094    33.529124     0.382860
# min        9.000000 -17051.000000 -14425.000000  -201.000000     0.000000
# 25%      160.000000  -1191.000000  -1132.500000   -17.000000     0.000000
# 50%      207.000000      0.000000      0.000000     0.000000     0.000000
# 75%      243.000000   1191.000000   1132.500000    17.000000     0.000000
# max     1011.000000  17051.000000  14425.000000   201.000000    16.000000
#
#         assistsat25   deathsat25 opp_killsat25 opp_assistsat25 opp_deathsat25
# count   9300.000000  9300.000000   9300.000000     9300.000000    9300.000000
# unique          NaN          NaN           NaN             NaN            NaN
# top             NaN          NaN           NaN             NaN            NaN
# freq            NaN          NaN           NaN             NaN            NaN
# mean       0.056774     0.027527      0.027312        0.056774       0.027527
# std        0.791803     0.381719      0.382860        0.791803       0.381719
# min        0.000000     0.000000      0.000000        0.000000       0.000000
# 25%        0.000000     0.000000      0.000000        0.000000       0.000000
# 50%        0.000000     0.000000      0.000000        0.000000       0.000000
# 75%        0.000000     0.000000      0.000000        0.000000       0.000000
# max       36.000000    16.000000     16.000000       36.000000      16.000000
#
# [11 rows x 161 columns]

# %%
from plotnine import ggplot, aes, geom_bar, ggtitle, labs, theme

# Carregar e filtrar dados
df = pd.read_csv('lol.csv')
df = df[(df['datacompleteness'] == 'complete') & (df['participantid'].isin([100,200]))]
# Out:
# <ipython-input-1-a6c827db2075>:8: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
print(f"Shape: {df.shape}")
print("\nInformações básicas:")
print(df.info())
print("\nValores únicos por coluna:")
print(df.nunique())
print("\nEstatísticas descritivas:")
print(df.describe(include='all'))
# Out:
# Shape: (1646, 161)
#
# Informações básicas:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1646 entries, 10 to 10799
# Columns: 161 entries, gameid to opp_deathsat25
# dtypes: float64(118), int64(20), object(23)
# memory usage: 2.0+ MB
# None
#
# Valores únicos por coluna:
# gameid              823
# datacompleteness      1
# url                   0
# league               22
# year                  1
#                    ...
# assistsat25          13
# deathsat25            9
# opp_killsat25         9
# opp_assistsat25      13
# opp_deathsat25        9
# Length: 161, dtype: int64
#
# Estatísticas descritivas:
#                   gameid datacompleteness  url league    year   split  \
# count               1646             1646    0   1646  1646.0    1530
# unique               823                1    0     22     NaN       7
# top     LOLTMNT03_179647         complete  NaN    LCK     NaN  Winter
# freq                   2             1646  NaN    164     NaN     796
# mean                 NaN              NaN  NaN    NaN  2025.0     NaN
# std                  NaN              NaN  NaN    NaN     0.0     NaN
# min                  NaN              NaN  NaN    NaN  2025.0     NaN
# 25%                  NaN              NaN  NaN    NaN  2025.0     NaN
# 50%                  NaN              NaN  NaN    NaN  2025.0     NaN
# 75%                  NaN              NaN  NaN    NaN  2025.0     NaN
# max                  NaN              NaN  NaN    NaN  2025.0     NaN
#
#         playoffs                 date         game        patch  ...  \
# count     1646.0                 1646  1646.000000  1646.000000  ...
# unique       NaN                  822          NaN          NaN  ...
# top          NaN  2025-02-05 20:08:47          NaN          NaN  ...
# freq         NaN                    4          NaN          NaN  ...
# mean         0.0                  NaN     1.428919    15.018190  ...
# std          0.0                  NaN     0.698754     0.006634  ...
# min          0.0                  NaN     1.000000    15.010000  ...
# 25%          0.0                  NaN     1.000000    15.010000  ...
# 50%          0.0                  NaN     1.000000    15.020000  ...
# 75%          0.0                  NaN     2.000000    15.020000  ...
# max          0.0                  NaN     5.000000    15.030000  ...
#
#          opp_csat25 golddiffat25    xpdiffat25   csdiffat25    killsat25  \
# count   1550.000000   1550.00000   1550.000000  1550.000000  1550.000000
# unique          NaN          NaN           NaN          NaN          NaN
# top             NaN          NaN           NaN          NaN          NaN
# freq            NaN          NaN           NaN          NaN          NaN
# mean     842.058065      0.00000      0.000000     0.000000     0.081935
# std       58.614137   5975.78269   5238.573635    57.204965     0.815677
# min      634.000000 -17051.00000 -14425.000000  -178.000000     0.000000
# 25%      803.250000  -4067.00000  -3645.250000   -39.000000     0.000000
# 50%      844.000000      0.00000      0.000000     0.000000     0.000000
# 75%      883.000000   4067.00000   3645.250000    39.000000     0.000000
# max     1011.000000  17051.00000  14425.000000   178.000000    16.000000
#
#         assistsat25   deathsat25 opp_killsat25 opp_assistsat25 opp_deathsat25
# count   1550.000000  1550.000000   1550.000000     1550.000000    1550.000000
# unique          NaN          NaN           NaN             NaN            NaN
# top             NaN          NaN           NaN             NaN            NaN
# freq            NaN          NaN           NaN             NaN            NaN
# mean       0.170323     0.082581      0.081935        0.170323       0.082581
# std        1.731312     0.824664      0.815677        1.731312       0.824664
# min        0.000000     0.000000      0.000000        0.000000       0.000000
# 25%        0.000000     0.000000      0.000000        0.000000       0.000000
# 50%        0.000000     0.000000      0.000000        0.000000       0.000000
# 75%        0.000000     0.000000      0.000000        0.000000       0.000000
# max       36.000000    16.000000     16.000000       36.000000      16.000000
#
# [11 rows x 161 columns]

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='result', data=df)
plt.title('Distribuição da Variável Target (Result)')
plt.show()

print("\nProporção de vitórias:")
print(df['result'].value_counts(normalize=True))
# Out:
# Proporção de vitórias:
# result
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
economy_vars = ['totalgold','earnedgold','goldat10','goldat15','golddiffat10','golddiffat15']

plt.figure(figsize=(10,6))
sns.heatmap(df[economy_vars + ['result']].corr(), annot=True)
plt.title('Correlação entre Variáveis Econômicas e Resultado')
plt.show()

# %%
# !pip install met_brewer
# Out:
# Collecting met_brewer
#   Downloading met-brewer-1.0.2.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: colour>=0.1.5 in /usr/local/lib/python3.11/dist-packages (from met_brewer) (0.1.5)
# Requirement already satisfied: matplotlib>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from met_brewer) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->met_brewer) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->met_brewer) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->met_brewer) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->met_brewer) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->met_brewer) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->met_brewer) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->met_brewer) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->met_brewer) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->met_brewer) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.1->met_brewer) (1.17.0)
# Building wheels for collected packages: met_brewer
#   Building wheel for met_brewer (setup.py) ... done
#   Created wheel for met_brewer: filename=met_brewer-1.0.2-py3-none-any.whl size=11234 sha256=d1df32f17166b7ce37318eef3e7390bbdc3e4e5d931ea15bd4d0773327ffad72
#   Stored in directory: /root/.cache/pip/wheels/4c/56/d2/af72b048a8a0ad0589ab1f709f53a84778392be5893a810b4b
# Successfully built met_brewer
# Installing collected packages: met_brewer
# Successfully installed met_brewer-1.0.2

# %%
from plotnine import ggplot, aes, geom_bar, geom_text, ggtitle, labs, theme, scale_fill_manual
from met_brewer import met_brew

# Converte a variável 'result' para string (evita erro de escala)
df['result'] = df['result'].astype(str)

# Calcula os counts e porcentagens para cada categoria de 'result'
df_counts = df['result'].value_counts().rename_axis('result').reset_index(name='count')
df_counts['percentage'] = (df_counts['count'] / df_counts['count'].sum() * 100).round(1)
df_counts['percentage_label'] = df_counts['percentage'].astype(str) + '%'

# Define a paleta "Hokusai1" do MetBrewer
hokusai_palette = met_brew("Pillement", n=len(df_counts['result'].unique()), brew_type="discrete")

# Cria o gráfico
grafico = (ggplot(df, aes(x='result', fill='result')) +
           geom_bar(color='black') +
           geom_text(data=df_counts,
                     mapping=aes(x='result', y='count', label='percentage_label'),
                     va='bottom', nudge_y=10) +
           scale_fill_manual(values=hokusai_palette) +  # Usa a paleta MetBrewer
           ggtitle('') +
           labs(x='Result', y='Contagem', fill='Categoria') +
           theme(figure_size=(8, 6)))

print(grafico)

# Impressão da proporção de vitórias
print("\nProporção de vitórias:")
print(df['result'].value_counts(normalize=True))
# Out:
# <ggplot: (800 x 600)>
#
# Proporção de vitórias:
# result
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
grafico

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Definir uma paleta personalizada para se aproximar da paleta Pillment
pillment_colors = ["#f7fcf5", "#e5f5e0", "#c7e9c0", "#a1d99b", "#74c476"]

# Lista de objetivos
first_vars = ['firstblood', 'firstdragon', 'firstherald', 'firsttower', 'firstbaron']

# Configuração do gráfico
plt.figure(figsize=(12, 6))

# Criando os gráficos para cada variável
for i, var in enumerate(first_vars, 1):
    plt.subplot(2, 3, i)
    sns.barplot(x=var, y='result', data=df, errorbar=None, palette=pillment_colors)  # Aplica a paleta personalizada
    plt.title(f'Win Rate por {var}')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-158-09bbe77f3b0f>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# <ipython-input-158-09bbe77f3b0f>:18: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
# <ipython-input-158-09bbe77f3b0f>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# <ipython-input-158-09bbe77f3b0f>:18: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
# <ipython-input-158-09bbe77f3b0f>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# <ipython-input-158-09bbe77f3b0f>:18: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
# <ipython-input-158-09bbe77f3b0f>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# <ipython-input-158-09bbe77f3b0f>:18: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
# <ipython-input-158-09bbe77f3b0f>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# <ipython-input-158-09bbe77f3b0f>:18: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.

# %%
# Criar a tabela com a taxa de vitória por objetivo
win_rates = {var: df.groupby(var)['result'].mean() for var in first_vars}


win_rates_df = pd.DataFrame(win_rates).T
win_rates_df.columns = ["Taxa de Vitória (0)", "Taxa de Vitória (1)"]


print(win_rates_df)
# Out:
#              Taxa de Vitória (0)  Taxa de Vitória (1)
# firstblood              0.417983             0.582017
# firstdragon             0.445930             0.554070
# firstherald             0.339372             0.662592
# firsttower              0.301337             0.698663
# firstbaron              0.253823             0.863158

# %%
from plotnine import ggplot, aes, geom_bar, facet_wrap, labs, theme_minimal, scale_fill_manual
from met_brewer import met_brew

# Variável com os onjetivos
first_vars = ['firstblood', 'firstdragon', 'firstherald', 'firsttower', 'firstbaron']

# Definir a paleta "Pillement"  (para vitória e derrota)
pillment_palette = met_brew("Pillement", n=2, brew_type="discrete")


df_melted = df_filtered.melt(id_vars=['result'], value_vars=first_vars, var_name='first_objective', value_name='value')


plot = (ggplot(df_melted)
        + aes(x='value', fill='factor(result)')
        + geom_bar(stat='count', position='dodge')
        + facet_wrap('~first_objective', ncol=3)
        + labs(title='', x='First Objective', y='Contagem')
        + theme_minimal() +
        theme(figure_size=(8, 6))
        + scale_fill_manual(values=pillment_palette)  # Aplicando a paleta do MetBrewer
       )

print(plot)
# Out:
# <ggplot: (800 x 600)>

# %%
plot

# %%
fig, axs = plt.subplots(1,3, figsize=(18,5))
sns.boxplot(x='result', y='gamelength', data=df, ax=axs[0])
sns.countplot(x='year', hue='result', data=df, ax=axs[1])
sns.countplot(x='split', hue='result', data=df, ax=axs[2])
plt.tight_layout()

# %%
objectives = ['firstblood','firstdragon','firstherald','firstbaron','firsttower','elders','dragons','heralds']

plt.figure(figsize=(12,8))
df_objetivos = df.groupby('result')[objectives].mean().T
df_objetivos.plot(kind='barh', stacked=True)
plt.title('Média de Objetivos por Resultado')
plt.xlabel('Taxa de Conquista')
plt.show()

# %%
from plotnine import ggplot, aes, geom_bar, facet_wrap, labs, theme_minimal, scale_fill_manual, coord_flip



custom_palette = [ "#72898d", "#3f5a66", "#2d3d4b", "#0d1a21", "#a0714f", "#5c6c4d"]

# Agrupar e calcular a média
df_objetivos = df.groupby('result')[objectives].mean().reset_index()


df_long = df_objetivos.melt(id_vars='result', var_name='Objetivo', value_name='Taxa de Conquista')


g = (ggplot(df_long, aes(x='Objetivo', y='Taxa de Conquista', fill='factor(result)')) +
     geom_bar(stat='identity', position='dodge') +
     scale_fill_manual(values=custom_palette) +
     labs(title='Média de Objetivos por Resultado', x='Objetivo', y='Taxa de Conquista', fill='Resultado') +
     theme_minimal() +
     coord_flip())  # Inverte os eixos para barras horizontais

print(g)
# Out:
# <ggplot: (640 x 480)>

# %%
g

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


custom_palette = ["#a0714f", "#5c6c4d", "#72898d", "#3f5a66", "#2d3d4b", "#0d1a21"]

cmap = sns.color_palette(custom_palette, as_cmap=True)

economy_vars = ['totalgold','earnedgold','goldat10','goldat15', 'goldat20','golddiffat10','golddiffat15',
                'xpat10', 'csat10', 'xpat15', 'csat15', 'csdiffat15', 'xpdiffat10',
                'csdiffat10', 'xpdiffat15', 'golddiffat20','golddiffat20',
                'xpat20', 'csat20', 'xpat20', 'csat20', 'csdiffat20', 'xpdiffat20']

plt.figure(figsize=(15, 10))
sns.heatmap(df[economy_vars + ['result']].corr(), fmt=".2f", cmap=cmap, center=0, annot=True)
plt.title('')
plt.show()

# %%
combat_vars = ['kills','deaths','assists','teamkills','teamdeaths','doublekills','triplekills']

fig, axs = plt.subplots(2,2, figsize=(15,10))
sns.boxplot(x='result', y='kills', data=df, ax=axs[0,0])
sns.boxplot(x='result', y='deaths', data=df, ax=axs[0,1])
sns.scatterplot(x='kills', y='deaths', hue='result', data=df, ax=axs[1,0])
sns.countplot(x='firstblood', hue='result', data=df, ax=axs[1,1])
plt.tight_layout()

# %%
vision_vars = ['wardsplaced','wardskilled','controlwardsbought','visionscore']

plt.figure(figsize=(10,6))
sns.pairplot(df[vision_vars + ['result']], hue='result')
plt.suptitle('Análise de Variáveis de Visão', y=1.02)
plt.show()

# %%
time_vars = ['year','split','playoffs','patch']

plt.figure(figsize=(12,6))
sns.countplot(x='patch', hue='result', data=df)
plt.title('Distribuição de Resultados por Versão do Jogo')
plt.xticks(rotation=45)
plt.show()

# %%
corr_matrix = df.corr(numeric_only=True)
top_corr = corr_matrix['result'].abs().sort_values(ascending=False).head(16)[1:]
top_corr.to_frame('Correlação com Resultado').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_67cde_row0_col0, #T_67cde_row1_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_67cde_row2_col0 {
#   background-color: #addc30;
#   color: #000000;
# }
# #T_67cde_row3_col0 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_67cde_row4_col0, #T_67cde_row5_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_67cde_row6_col0 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_67cde_row7_col0 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_67cde_row8_col0 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_67cde_row9_col0, #T_67cde_row10_col0 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_67cde_row11_col0, #T_67cde_row12_col0 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_67cde_row13_col0 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_67cde_row14_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_67cde" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67cde_level0_col0" class="col_heading level0 col0" >Correlação com Resultado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67cde_level0_row0" class="row_heading level0 row0" >towers</th>
#       <td id="T_67cde_row0_col0" class="data row0 col0" >0.894316</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row1" class="row_heading level0 row1" >opp_towers</th>
#       <td id="T_67cde_row1_col0" class="data row1 col0" >0.894316</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row2" class="row_heading level0 row2" >earned gpm</th>
#       <td id="T_67cde_row2_col0" class="data row2 col0" >0.865648</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row3" class="row_heading level0 row3" >gspd</th>
#       <td id="T_67cde_row3_col0" class="data row3 col0" >0.795946</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row4" class="row_heading level0 row4" >opp_inhibitors</th>
#       <td id="T_67cde_row4_col0" class="data row4 col0" >0.765282</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row5" class="row_heading level0 row5" >inhibitors</th>
#       <td id="T_67cde_row5_col0" class="data row5 col0" >0.765282</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row6" class="row_heading level0 row6" >gpr</th>
#       <td id="T_67cde_row6_col0" class="data row6 col0" >0.731079</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row7" class="row_heading level0 row7" >team kpm</th>
#       <td id="T_67cde_row7_col0" class="data row7 col0" >0.707610</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row8" class="row_heading level0 row8" >assists</th>
#       <td id="T_67cde_row8_col0" class="data row8 col0" >0.692096</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row9" class="row_heading level0 row9" >kills</th>
#       <td id="T_67cde_row9_col0" class="data row9 col0" >0.685938</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row10" class="row_heading level0 row10" >teamkills</th>
#       <td id="T_67cde_row10_col0" class="data row10 col0" >0.685938</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row11" class="row_heading level0 row11" >deaths</th>
#       <td id="T_67cde_row11_col0" class="data row11 col0" >0.684676</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row12" class="row_heading level0 row12" >teamdeaths</th>
#       <td id="T_67cde_row12_col0" class="data row12 col0" >0.684676</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row13" class="row_heading level0 row13" >golddiffat25</th>
#       <td id="T_67cde_row13_col0" class="data row13 col0" >0.679585</td>
#     </tr>
#     <tr>
#       <th id="T_67cde_level0_row14" class="row_heading level0 row14" >xpdiffat25</th>
#       <td id="T_67cde_row14_col0" class="data row14 col0" >0.663014</td>
#     </tr>
#   </tbody>
# </table>

# %%
obj_table = pd.pivot_table(df, index='result', values=['firstblood','firstdragon','firstherald','firstbaron'], aggfunc='mean')
print(obj_table.T)
# Out:
# result              0         1
# firstbaron   0.110571  0.697448
# firstblood   0.417983  0.582017
# firstdragon  0.445930  0.554070
# firstherald  0.335358  0.658566

# %%
economy_table = df.groupby('result')[['goldat10','goldat15','goldat20','golddiffat10','golddiffat15']].mean()
economy_table.apply(lambda x: round(x/1000,1))
# Out:
#         goldat10  goldat15  goldat20  golddiffat10  golddiffat15
# result
# 0           15.6      24.1      32.9          -0.5          -1.5
# 1           16.2      25.6      35.7           0.5           1.5

# %%
multi_kills = df.groupby('result')[['doublekills','triplekills','quadrakills','pentakills']].sum()
multi_kills.style.format('{:.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_50312" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50312_level0_col0" class="col_heading level0 col0" >doublekills</th>
#       <th id="T_50312_level0_col1" class="col_heading level0 col1" >triplekills</th>
#       <th id="T_50312_level0_col2" class="col_heading level0 col2" >quadrakills</th>
#       <th id="T_50312_level0_col3" class="col_heading level0 col3" >pentakills</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >result</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50312_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50312_row0_col0" class="data row0 col0" >658</td>
#       <td id="T_50312_row0_col1" class="data row0 col1" >78</td>
#       <td id="T_50312_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_50312_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_50312_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50312_row1_col0" class="data row1 col0" >2272</td>
#       <td id="T_50312_row1_col1" class="data row1 col1" >414</td>
#       <td id="T_50312_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_50312_row1_col3" class="data row1 col3" >10</td>
#     </tr>
#   </tbody>
# </table>

# %%
vision_table = df.groupby('result')[['wardsplaced','wardskilled','controlwardsbought']].mean().round(1)
vision_table.style.format('{:.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b2d7e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2d7e_level0_col0" class="col_heading level0 col0" >wardsplaced</th>
#       <th id="T_b2d7e_level0_col1" class="col_heading level0 col1" >wardskilled</th>
#       <th id="T_b2d7e_level0_col2" class="col_heading level0 col2" >controlwardsbought</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >result</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2d7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b2d7e_row0_col0" class="data row0 col0" >98</td>
#       <td id="T_b2d7e_row0_col1" class="data row0 col1" >41</td>
#       <td id="T_b2d7e_row0_col2" class="data row0 col2" >34</td>
#     </tr>
#     <tr>
#       <th id="T_b2d7e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b2d7e_row1_col0" class="data row1 col0" >102</td>
#       <td id="T_b2d7e_row1_col1" class="data row1 col1" >44</td>
#       <td id="T_b2d7e_row1_col2" class="data row1 col2" >36</td>
#     </tr>
#   </tbody>
# </table>

# %%
champ_winrate = df.groupby('champion')['result'].agg(['count','mean']).query('count >= 50').sort_values('mean', ascending=False).head(10)
champ_winrate.style.format({'mean': '{:.2%}', 'count': '{:.0f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_9284f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9284f_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_9284f_level0_col1" class="col_heading level0 col1" >mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >champion</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
#Análise de Win Rate
df = df.rename(columns={'champion': 'player_champion'})


picks_columns = ['pick1','pick2','pick3','pick4','pick5']
champ_data = df.melt(
    id_vars=['gameid','result'],
    value_vars=picks_columns,
    var_name='pick_position',
    value_name='picked_champion'
)


champ_winrate = (champ_data.groupby('picked_champion')['result']
                 .agg(games=('count'), win_rate=('mean'))
                 .query('games >= 50')
                 .sort_values('win_rate', ascending=False)
                 .head(10))


champ_winrate.style.format({'win_rate': '{:.2%}', 'games': '{:.0f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_452aa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_452aa_level0_col0" class="col_heading level0 col0" >games</th>
#       <th id="T_452aa_level0_col1" class="col_heading level0 col1" >win_rate</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >picked_champion</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_452aa_level0_row0" class="row_heading level0 row0" >Xayah</th>
#       <td id="T_452aa_row0_col0" class="data row0 col0" >53</td>
#       <td id="T_452aa_row0_col1" class="data row0 col1" >62.26%</td>
#     </tr>
#     <tr>
#       <th id="T_452aa_level0_row1" class="row_heading level0 row1" >Poppy</th>
#       <td id="T_452aa_row1_col0" class="data row1 col0" >112</td>
#       <td id="T_452aa_row1_col1" class="data row1 col1" >61.61%</td>
#     </tr>
#     <tr>
#       <th id="T_452aa_level0_row2" class="row_heading level0 row2" >Kai'Sa</th>
#       <td id="T_452aa_row2_col0" class="data row2 col0" >134</td>
#       <td id="T_452aa_row2_col1" class="data row2 col1" >60.45%</td>
#     </tr>
#     <tr>
#       <th id="T_452aa_level0_row3" class="row_heading level0 row3" >Rumble</th>
#       <td id="T_452aa_row3_col0" class="data row3 col0" >174</td>
#       <td id="T_452aa_row3_col1" class="data row3 col1" >59.77%</td>
#     </tr>
#     <tr>
#       <th id="T_452aa_level0_row4" class="row_heading level0 row4" >Viego</th>
#       <td id="T_452aa_row4_col0" class="data row4 col0" >124</td>
#       <td id="T_452aa_row4_col1" class="data row4 col1" >58.87%</td>
#     </tr>
#     <tr>
#       <th id="T_452aa_level0_row5" class="row_heading level0 row5" >Nautilus</th>
#       <td id="T_452aa_row5_col0" class="data row5 col0" >168</td>
#       <td id="T_452aa_row5_col1" class="data row5 col1" >58.33%</td>
#     </tr>
#     <tr>
#       <th id="T_452aa_level0_row6" class="row_heading level0 row6" >Pantheon</th>
#       <td id="T_452aa_row6_col0" class="data row6 col0" >54</td>
#       <td id="T_452aa_row6_col1" class="data row6 col1" >57.41%</td>
#     </tr>
#     <tr>
#       <th id="T_452aa_level0_row7" class="row_heading level0 row7" >Taliyah</th>
#       <td id="T_452aa_row7_col0" class="data row7 col0" >111</td>
#       <td id="T_452aa_row7_col1" class="data row7 col1" >56.76%</td>
#     </tr>
#     <tr>
#       <th id="T_452aa_level0_row8" class="row_heading level0 row8" >Skarner</th>
#       <td id="T_452aa_row8_col0" class="data row8 col0" >71</td>
#       <td id="T_452aa_row8_col1" class="data row8 col1" >56.34%</td>
#     </tr>
#     <tr>
#       <th id="T_452aa_level0_row9" class="row_heading level0 row9" >Yone</th>
#       <td id="T_452aa_row9_col0" class="data row9 col0" >121</td>
#       <td id="T_452aa_row9_col1" class="data row9 col1" >55.37%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Ban vs Win Rate
ban_columns = ['ban1','ban2','ban3','ban4','ban5']
ban_data = df.melt(id_vars=['gameid'],
                  value_vars=ban_columns,
                  value_name='banned_champion')

ban_analysis = (ban_data.groupby('banned_champion')['gameid']
                .nunique()
                .sort_values(ascending=False)
                .head(20))
print(ban_analysis)
# Out:
# banned_champion
# Skarner     702
# Kalista     489
# K'Sante     330
# Varus       292
# Ambessa     263
# Corki       253
# Vi          235
# Aurora      229
# Maokai      223
# Rumble      220
# Poppy       210
# Viktor      206
# Zyra        199
# Jayce       192
# Nocturne    173
# Ashe        154
# Orianna     153
# Rell        145
# Sejuani     141
# Yone        140
# Name: gameid, dtype: int64
